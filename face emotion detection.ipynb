# %%
import cv2

# %%
import cv2

# %%
from deepface import DeepFace

# %%
import matplotlib.pyplot as plt

# %%
img_path = r'C:\Users\hai\Desktop\dspl\happyboy.jpg'
img = cv2.imread(img_path)

# %%
print(img)
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
plt.imshow(img)

# %%
predictions = DeepFace.stream(img_path)
predictions
if cv2.waitkey(20) & 0xFF==27:
    break
    cv2.destroyAllWindows()
# Out:
# Detector backend is  opencv
# WARNING: There is no image in this path (  C:\Users\hai\Desktop\dspl\happyboy.jpg ) . Face recognition will not be performed.
# Emotion model loaded
# Age model loaded
# Gender model loaded
# Facial attibute analysis models loaded in  34.77932000160217  seconds
# Finding embeddings: 0it [00:00, ?it/s]
# Embeddings found for given data set in  5.451782464981079  seconds

# %%
predictions['dominant_emotion']

# %%
x=(["angry","disgust","fear","sad","surprise","neutral","happy",])
y=([4.194, 9.5362,7.2837,7.3196, 1.2050,2.0170,100.0])
plt.xlabel("emotion")
plt.ylabel("range")
plt.bar(x,y)
# Out:
# <BarContainer object of 7 artists>

# %%
type(predictions)
# Out:
# dict

# %%
faceCascade =cv2.CascadeClassifier(cv2.data.haarcascades +'haarcascade_frontalface_default.xml')

# %%
gray =cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
faces = faceCascade.detectMultiScale(gray,1.1,4)
for(x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img,
           predictions['dominant_emotion'],
           (0,50),
           font,1,
           (0,0,255),
           2,
           cv2.LINE_4);

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
img3=cv2.imread(r"C:\Users\hai\Pictures\fear.jpg")
plt.imshow(img3)

# %%
plt.imshow(cv2.cvtColor(img3, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img3,actions=["emotion"])
# Out:
# 1/1 [==============================] - 0s 42ms/step

# %%
predictions
# Out:
# {'emotion': {'angry': 2.910476304407439e-08,
#   'disgust': 2.205007240557258e-19,
#   'fear': 0.08878001826815307,
#   'happy': 1.5817218468328065e-05,
#   'sad': 1.4045665767493319e-15,
#   'surprise': 99.9112069606781,
#   'neutral': 3.538517748023317e-18},
#  'dominant_emotion': 'surprise',
#  'region': {'x': 459, 'y': 129, 'w': 344, 'h': 344}}

# %%
gray =cv2.cvtColor(img3,cv2.COLOR_BGR2GRAY)
faces = faceCascade.detectMultiScale(gray,1.1,4)
for(x,y,w,h) in faces:
    cv2.rectangle(img3,(x,y),(x+w,y+h),(200,0,0),2)

# %%
plt.imshow(cv2.cvtColor(img3, cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img3,
           predictions['dominant_emotion'],
           (0,50),
           font,1,
           (0,255,0),
           2,
           cv2.LINE_4);

# %%
plt.imshow(cv2.cvtColor(img3, cv2.COLOR_BGR2RGB))

# %%
img5=cv2.imread(r"C:\Users\hai\Desktop\dspl\images (2).jpg")
plt.imshow(img5)

# %%
plt.imshow(cv2.cvtColor(img5, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img5,actions=['emotion'])
# Out:
# 1/1 [==============================] - 0s 41ms/step

# %%
predictions
# Out:
# {'emotion': {'angry': 99.69367383084737,
#   'disgust': 0.29898704414737487,
#   'fear': 0.002361176079595712,
#   'happy': 1.2951934519724529e-06,
#   'sad': 0.004863284192397435,
#   'surprise': 0.00010453665650030809,
#   'neutral': 6.875313528626564e-06},
#  'dominant_emotion': 'angry',
#  'region': {'x': 102, 'y': 45, 'w': 104, 'h': 104}}

# %%
plt.imshow(cv2.cvtColor(img6, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img6,actions=['emotion'])
# Out:
# 1/1 [==============================] - 0s 50ms/step

# %%
predictions
# Out:
# {'emotion': {'angry': 19.294627010822296,
#   'disgust': 8.890007165973657e-05,
#   'fear': 28.70621085166931,
#   'happy': 0.00014826467804596177,
#   'sad': 40.17115533351898,
#   'surprise': 5.7492320593155455e-05,
#   'neutral': 11.827706545591354},
#  'dominant_emotion': 'sad',
#  'region': {'x': 155, 'y': 33, 'w': 50, 'h': 50}}

# %%
img9=cv2.imread(r"C:\Users\hai\Desktop\images (18).jpg")
plt.imshow(img9)

# %%
pre=DeepFace.analyze(img9,actions=['emotion'])
pre
# Out:
# 1/1 [==============================] - 0s 50ms/step
# {'emotion': {'angry': 3.111673148074967,
#   'disgust': 81.45764691142476,
#   'fear': 15.306123756632356,
#   'happy': 3.669218446878585e-06,
#   'sad': 0.12401903199550128,
#   'surprise': 0.0004627987794629356,
#   'neutral': 6.57937483777294e-05},
#  'dominant_emotion': 'disgust',
#  'region': {'x': 71, 'y': 35, 'w': 109, 'h': 109}}

# %%
img9=cv2.imread(r"C:\Users\hai\Pictures\cricket.jpg")
plt.imshow(img9)

# %%
plt.imshow(cv2.cvtColor(img9, cv2.COLOR_BGR2RGB))

# %%
pre=DeepFace.analyze(img9,actions=['emotion'])
pre
# Out:
# 1/1 [==============================] - 0s 40ms/step
# {'emotion': {'angry': 3.817914343724925,
#   'disgust': 5.931947558781549e-07,
#   'fear': 0.09488493702814733,
#   'happy': 0.0133932464855392,
#   'sad': 5.720448557084971,
#   'surprise': 0.005036530765075295,
#   'neutral': 90.34831638952298},
#  'dominant_emotion': 'neutral',
#  'region': {'x': 49, 'y': 30, 'w': 154, 'h': 154}}

# %%
gray =cv2.cvtColor(img9,cv2.COLOR_BGR2GRAY)
faces = faceCascade.detectMultiScale(gray,1.1,4)
for(x,y,w,h) in faces:
    cv2.rectangle(img9,(x,y),(x+w,y+h),(0,255,0),2)

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img9,
           predictions['dominant_emotion'],
           (0,50),
           font,1,
           (0,255,0),
           2,
           cv2.LINE_4);

# %%
plt.imshow(cv2.cvtColor(img9, cv2.COLOR_BGR2RGB))

# %%
img=cv2.imread(r"C:\Users\hai\Pictures\haiii (2).jpg")
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
pre=DeepFace.analyze(img,actions=['emotion'])
pre
# Out:
# 1/1 [==============================] - 0s 70ms/step
# {'emotion': {'angry': 0.0016708461771486327,
#   'disgust': 1.977123499641298e-09,
#   'fear': 0.00010661182159310556,
#   'happy': 86.3515555858612,
#   'sad': 0.023141644487623125,
#   'surprise': 0.0679889926686883,
#   'neutral': 13.555534183979034},
#  'dominant_emotion': 'happy',
#  'region': {'x': 127, 'y': 29, 'w': 196, 'h': 196}}

# %%
pre['dominant_emotion']
# Out:
# 'happy'

# %%
img=cv2.imread(r"C:\Users\hai\Pictures\hai.webp")

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
pre=DeepFace.analyze(img)
pre
# Out:
# 1/1 [==============================] - 0s 50ms/step
# {'emotion': {'angry': 0.011564043234102428,
#   'disgust': 1.8673341983799219e-06,
#   'fear': 4.828995514571943e-06,
#   'happy': 87.91942000389099,
#   'sad': 0.002463540658936836,
#   'surprise': 0.0020070719983777963,
#   'neutral': 12.06454485654831},
#  'dominant_emotion': 'happy',
#  'region': {'x': 482, 'y': 177, 'w': 346, 'h': 346}}

# %%
pre['dominant_emotion']
# Out:
# 'happy'
